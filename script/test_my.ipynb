# %%
import pickle
with open("")

# %%
# Out:
# HEADER(flag=2, label=array([0., 0.], dtype=float32), id=1, id2=0)

# %%
# Out:
# (HEADER(flag=2, label=array([144.,   0.], dtype=float32), id=10000, id2=0),
# ...

# %%
# Out:
# HEADER(flag=2, label=array([144.,   0.], dtype=float32), id=10001, id2=0)
